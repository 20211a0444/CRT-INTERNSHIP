# %% [markdown]
# **Importing Libraries**

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# **Laoding and Preprocessing the Dataset**

# %%
(x_train,y_train),(x_test,y_test)=keras.datasets.mnist.load_data()

x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0

x_train=x_train.reshape(-1,28*28)
x_test=x_test.reshape(-1,28*28)

# %% [markdown]
# **Model Architecture**

# %%
model=keras.Sequential([
    keras.layers.Dense(128,activation='relu',input_shape=(28*28,)),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10,activation='softmax')
])

# %% [markdown]
# **Train the model**

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train,y_train,epochs=5,batch_size=64)
# Out:
# Epoch 1/5
# 938/938 [==============================] - 4s 3ms/step - loss: 0.3414 - accuracy: 0.9025
# Epoch 2/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1645 - accuracy: 0.9514
# Epoch 3/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1227 - accuracy: 0.9635
# Epoch 4/5
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1002 - accuracy: 0.9693
# Epoch 5/5
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0853 - accuracy: 0.9736

# %% [markdown]
# **Evaluate the model**

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Test accuracy:',test_acc)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 0.9764
# Test accuracy: 0.9764000177383423

# %% [markdown]
# **Make Predictions**

# %%
predictions=model.predict(x_test[:5])
predicted_labels=[tf.argmax(prediction).numpy() for prediction in predictions]

print('Predicted labels:',predicted_labels)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# Predicted labels: [7, 2, 1, 0, 4]
